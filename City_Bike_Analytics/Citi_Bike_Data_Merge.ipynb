# %%
import csv
import pandas as pd

# %%
df_jan17 = pd.read_csv("data/JC-201701-citibike-tripdata.csv")
df_feb17 = pd.read_csv("data/JC-201702-citibike-tripdata.csv")
df_mar17 = pd.read_csv("data/JC-201703-citibike-tripdata.csv")
df_apr17 = pd.read_csv("data/JC-201704-citibike-tripdata.csv")
df_may17 = pd.read_csv("data/JC-201705-citibike-tripdata.csv")
df_jun17 = pd.read_csv("data/JC-201706-citibike-tripdata.csv")
df_jul17 = pd.read_csv("data/JC-201707-citibike-tripdata.csv")
df_aug17 = pd.read_csv("data/JC-201708 citibike-tripdata.csv")
df_sep17 = pd.read_csv("data/JC-201709-citibike-tripdata.csv")
df_oct17 = pd.read_csv("data/JC-201710-citibike-tripdata.csv")
df_nov17 = pd.read_csv("data/JC-201711-citibike-tripdata.csv")
df_dec17 = pd.read_csv("data/JC-201712-citibike-tripdata.csv")

# %%
df = pd.concat([df_jan17, df_feb17, df_mar17, df_apr17, df_may17, df_jun17, df_jun17, df_jul17, df_aug17, df_sep17, df_oct17, df_nov17, df_dec17], sort=True)

# %%
df.to_csv("data/citiBikedata_17.csv", encoding ="utf-8")

# %%
df.head()
# Out:
#    Bike ID  Birth Year  End Station ID  End Station Latitude  \
# 0      NaN         NaN             NaN                   NaN
# 1      NaN         NaN             NaN                   NaN
# 2      NaN         NaN             NaN                   NaN
# 3      NaN         NaN             NaN                   NaN
# 4      NaN         NaN             NaN                   NaN
#
#    End Station Longitude End Station Name  Gender  Start Station ID  \
# 0                    NaN              NaN     NaN               NaN
# 1                    NaN              NaN     NaN               NaN
# 2                    NaN              NaN     NaN               NaN
# 3                    NaN              NaN     NaN               NaN
# 4                    NaN              NaN     NaN               NaN
#
#    Start Station Latitude  Start Station Longitude     ...      \
# 0                     NaN                      NaN     ...
# 1                     NaN                      NaN     ...
# ...
